# %% [markdown]
# <div class="alert alert-block alert-info">
# <center>ESTATÍSTICA APLICADA</center>
# <center>Projeto II</center>
# <center>ALUNO: Lucas Matheus Gomes de Lima.</center>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-block alert-info">
# 1. Preparação dos dados para a análise
# Antes de iniciar sua análise, é fundamental que você primeiro examine e limpe o conjunto de
# dados, para tornar o trabalho com ele um processo mais eficiente. Nesta parte, você praticará a
# correção de tipos de dados, manipulação de valores ausentes e eliminação de colunas e linhas
# enquanto aprende sobre o conjunto de dados do Stanford Open Policing Project.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (a) Importe o dataset police.csv, e indique quantas variáveis estão disponíveis e quantos
# registros policiais estão catalogados;
# </div>

# %%
df = pd.read_csv("https://github.com/lucasgomes14/Estatistica/blob/dace9ea0450ea6c6bc3296df3feb244b5cafcf59/Projetos/Projeto%202/police.csv")
df2 = pd.read_csv("https://github.com/lucasgomes14/Estatistica/blob/dace9ea0450ea6c6bc3296df3feb244b5cafcf59/Projetos/Projeto%202/weather.csv")
df
# Out:
#       state   stop_date stop_time  county_name driver_gender driver_race  \
# 0        RI  2005-01-04     12:55          NaN             M       White
# 1        RI  2005-01-23     23:15          NaN             M       White
# 2        RI  2005-02-17     04:15          NaN             M       White
# 3        RI  2005-02-20     17:15          NaN             M       White
# 4        RI  2005-02-24     01:20          NaN             F       White
# ...     ...         ...       ...          ...           ...         ...
# 91736    RI  2015-12-31     21:21          NaN             F       Black
# 91737    RI  2015-12-31     21:59          NaN             F       White
# 91738    RI  2015-12-31     22:04          NaN             M       White
# 91739    RI  2015-12-31     22:09          NaN             F    Hispanic
# 91740    RI  2015-12-31     22:47          NaN             M       White
#
#                         violation_raw            violation  search_conducted  \
# 0      Equipment/Inspection Violation            Equipment             False
# 1                            Speeding             Speeding             False
# 2                            Speeding             Speeding             False
# 3                    Call for Service                Other             False
# 4                            Speeding             Speeding             False
# ...                               ...                  ...               ...
# 91736         Other Traffic Violation     Moving violation             False
# 91737                        Speeding             Speeding             False
# 91738         Other Traffic Violation     Moving violation             False
# 91739  Equipment/Inspection Violation            Equipment             False
# 91740          Registration Violation  Registration/plates             False
#
#       search_type   stop_outcome is_arrested stop_duration  \
# 0             NaN       Citation       False      0-15 Min
# 1             NaN       Citation       False      0-15 Min
# 2             NaN       Citation       False      0-15 Min
# 3             NaN  Arrest Driver        True     16-30 Min
# 4             NaN       Citation       False      0-15 Min
# ...           ...            ...         ...           ...
# 91736         NaN       Citation       False      0-15 Min
# 91737         NaN       Citation       False      0-15 Min
# 91738         NaN       Citation       False      0-15 Min
# 91739         NaN        Warning       False      0-15 Min
# 91740         NaN       Citation       False      0-15 Min
#
#        drugs_related_stop district
# 0                   False  Zone X4
# 1                   False  Zone K3
# 2                   False  Zone X4
# 3                   False  Zone X1
# 4                   False  Zone X3
# ...                   ...      ...
# 91736               False  Zone K2
# 91737               False  Zone K3
# 91738               False  Zone X3
# 91739               False  Zone K3
# 91740               False  Zone X4
#
# [91741 rows x 15 columns]

# %%
df.shape[1]
# Out:
# 15

# %%
df.shape[0]
# Out:
# 91741

# %% [markdown]
# <span style="color:blue">**Existe 15 variáveis e 91741 registros no dataframe.**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (b) Conte o número de dados faltosos de cada variável;
# </div>

# %%
df.isnull().sum()
# Out:
# state                     0
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5205
# driver_race            5202
# violation_raw          5202
# violation              5202
# search_conducted          0
# search_type           88434
# stop_outcome           5202
# is_arrested            5202
# stop_duration          5202
# drugs_related_stop        0
# district                  0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 216592

# %% [markdown]
# <span style="color:blue">**Existe 216592 dados faltosos no dataframe.**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (c) Como estamos trabalhando somente com dados de um único estado, não faz sentido
# mantermos informações de variáveis como county_name e state. Exclua essas variáveis
# do conjunto;
# </div>

# %%
df.drop(["county_name","state"], axis = 1) #remoção do county e state
# Out:
#         stop_date stop_time driver_gender driver_race  \
# 0      2005-01-04     12:55             M       White
# 1      2005-01-23     23:15             M       White
# 2      2005-02-17     04:15             M       White
# 3      2005-02-20     17:15             M       White
# 4      2005-02-24     01:20             F       White
# ...           ...       ...           ...         ...
# 91736  2015-12-31     21:21             F       Black
# 91737  2015-12-31     21:59             F       White
# 91738  2015-12-31     22:04             M       White
# 91739  2015-12-31     22:09             F    Hispanic
# 91740  2015-12-31     22:47             M       White
#
#                         violation_raw            violation  search_conducted  \
# 0      Equipment/Inspection Violation            Equipment             False
# 1                            Speeding             Speeding             False
# 2                            Speeding             Speeding             False
# 3                    Call for Service                Other             False
# 4                            Speeding             Speeding             False
# ...                               ...                  ...               ...
# 91736         Other Traffic Violation     Moving violation             False
# 91737                        Speeding             Speeding             False
# 91738         Other Traffic Violation     Moving violation             False
# 91739  Equipment/Inspection Violation            Equipment             False
# 91740          Registration Violation  Registration/plates             False
#
#       search_type   stop_outcome is_arrested stop_duration  \
# 0             NaN       Citation       False      0-15 Min
# 1             NaN       Citation       False      0-15 Min
# 2             NaN       Citation       False      0-15 Min
# 3             NaN  Arrest Driver        True     16-30 Min
# 4             NaN       Citation       False      0-15 Min
# ...           ...            ...         ...           ...
# 91736         NaN       Citation       False      0-15 Min
# 91737         NaN       Citation       False      0-15 Min
# 91738         NaN       Citation       False      0-15 Min
# 91739         NaN        Warning       False      0-15 Min
# 91740         NaN       Citation       False      0-15 Min
#
#        drugs_related_stop district
# 0                   False  Zone X4
# 1                   False  Zone K3
# 2                   False  Zone X4
# 3                   False  Zone X1
# 4                   False  Zone X3
# ...                   ...      ...
# 91736               False  Zone K2
# 91737               False  Zone K3
# 91738               False  Zone X3
# 91739               False  Zone K3
# 91740               False  Zone X4
#
# [91741 rows x 13 columns]

# %% [markdown]
# <span style="color:blue">**Apagado as colunas county_name e state do dataframe.**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (d) Durante as análises, a coluna driver_gender será crítica para muitas de suas análises.
# Como apenas uma pequena fração das linhas está faltando driver_gender, remova
# essas linhas do conjunto de dados;
# </div>

# %%
df.dropna(subset=["driver_gender"])
# Out:
#       state   stop_date stop_time  county_name driver_gender driver_race  \
# 0        RI  2005-01-04     12:55          NaN             M       White
# 1        RI  2005-01-23     23:15          NaN             M       White
# 2        RI  2005-02-17     04:15          NaN             M       White
# 3        RI  2005-02-20     17:15          NaN             M       White
# 4        RI  2005-02-24     01:20          NaN             F       White
# ...     ...         ...       ...          ...           ...         ...
# 91736    RI  2015-12-31     21:21          NaN             F       Black
# 91737    RI  2015-12-31     21:59          NaN             F       White
# 91738    RI  2015-12-31     22:04          NaN             M       White
# 91739    RI  2015-12-31     22:09          NaN             F    Hispanic
# 91740    RI  2015-12-31     22:47          NaN             M       White
#
#                         violation_raw            violation  search_conducted  \
# 0      Equipment/Inspection Violation            Equipment             False
# 1                            Speeding             Speeding             False
# 2                            Speeding             Speeding             False
# 3                    Call for Service                Other             False
# 4                            Speeding             Speeding             False
# ...                               ...                  ...               ...
# 91736         Other Traffic Violation     Moving violation             False
# 91737                        Speeding             Speeding             False
# 91738         Other Traffic Violation     Moving violation             False
# 91739  Equipment/Inspection Violation            Equipment             False
# 91740          Registration Violation  Registration/plates             False
#
#       search_type   stop_outcome is_arrested stop_duration  \
# 0             NaN       Citation       False      0-15 Min
# 1             NaN       Citation       False      0-15 Min
# 2             NaN       Citation       False      0-15 Min
# 3             NaN  Arrest Driver        True     16-30 Min
# 4             NaN       Citation       False      0-15 Min
# ...           ...            ...         ...           ...
# 91736         NaN       Citation       False      0-15 Min
# 91737         NaN       Citation       False      0-15 Min
# 91738         NaN       Citation       False      0-15 Min
# 91739         NaN        Warning       False      0-15 Min
# 91740         NaN       Citation       False      0-15 Min
#
#        drugs_related_stop district
# 0                   False  Zone X4
# 1                   False  Zone K3
# 2                   False  Zone X4
# 3                   False  Zone X1
# 4                   False  Zone X3
# ...                   ...      ...
# 91736               False  Zone K2
# 91737               False  Zone K3
# 91738               False  Zone X3
# 91739               False  Zone K3
# 91740               False  Zone X4
#
# [86536 rows x 15 columns]

# %% [markdown]
# <span style="color:blue">**Apagado as linhas que não tinham dados da coluna driver_gender do dataframe.**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (e) Vá na descrição dos dados e verifique que tipo de variável são search_conducted,
# is_arrested e district; depois compare com os tipos de dados que estão armazenados no conjunto de dados. Havendo necessidade, faça a modificação dos tipos de dados
# para essas variáveis;
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               91741 non-null  object
#  1   stop_date           91741 non-null  object
#  2   stop_time           91741 non-null  object
#  3   county_name         0 non-null      float64
#  4   driver_gender       86536 non-null  object
#  5   driver_race         86539 non-null  object
#  6   violation_raw       86539 non-null  object
#  7   violation           86539 non-null  object
#  8   search_conducted    91741 non-null  bool
#  9   search_type         3307 non-null   object
#  10  stop_outcome        86539 non-null  object
#  11  is_arrested         86539 non-null  object
#  12  stop_duration       86539 non-null  object
#  13  drugs_related_stop  91741 non-null  bool
#  14  district            91741 non-null  object
# dtypes: bool(2), float64(1), object(12)
# memory usage: 9.3+ MB

# %% [markdown]
# <span style="color:blue">**SEARCH_CONDUCTED = BOOL**</span>

# %% [markdown]
# <span style="color:blue">**IS_ARRESTED      = OBJECT**</span>

# %% [markdown]
# <span style="color:blue">**DISTRICT         = OBJECT**</span>

# %%
df["is_arrested"].astype(bool)
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 91736    False
# 91737    False
# 91738    False
# 91739    False
# 91740    False
# Name: is_arrested, Length: 91741, dtype: bool

# %% [markdown]
# <span style="color:blue">**CONVERTI IS ARRESTED PARA BOOL**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (f) A data e a hora de cada parada de tráfego estão armazenadas em colunas separadas:
# stop_date e stop_time. Combine essas duas colunas em uma única coluna, nomeando-
# a como stop_datetime e converta no formato data e hora (tipo datetime). Isso habi-
# litará atributos baseados em data convenientes que usaremos posteriormente no projeto;
# </div>

# %%
df["stop_datetime"] = df["stop_date"].map(str) + " " + df["stop_time"]
df.drop(["stop_date", "stop_time"], axis = 1)
# Out:
#       state  county_name driver_gender driver_race  \
# 0        RI          NaN             M       White
# 1        RI          NaN             M       White
# 2        RI          NaN             M       White
# 3        RI          NaN             M       White
# 4        RI          NaN             F       White
# ...     ...          ...           ...         ...
# 91736    RI          NaN             F       Black
# 91737    RI          NaN             F       White
# 91738    RI          NaN             M       White
# 91739    RI          NaN             F    Hispanic
# 91740    RI          NaN             M       White
#
#                         violation_raw            violation  search_conducted  \
# 0      Equipment/Inspection Violation            Equipment             False
# 1                            Speeding             Speeding             False
# 2                            Speeding             Speeding             False
# 3                    Call for Service                Other             False
# 4                            Speeding             Speeding             False
# ...                               ...                  ...               ...
# 91736         Other Traffic Violation     Moving violation             False
# 91737                        Speeding             Speeding             False
# 91738         Other Traffic Violation     Moving violation             False
# 91739  Equipment/Inspection Violation            Equipment             False
# 91740          Registration Violation  Registration/plates             False
#
#       search_type   stop_outcome is_arrested stop_duration  \
# 0             NaN       Citation       False      0-15 Min
# 1             NaN       Citation       False      0-15 Min
# 2             NaN       Citation       False      0-15 Min
# 3             NaN  Arrest Driver        True     16-30 Min
# 4             NaN       Citation       False      0-15 Min
# ...           ...            ...         ...           ...
# 91736         NaN       Citation       False      0-15 Min
# 91737         NaN       Citation       False      0-15 Min
# 91738         NaN       Citation       False      0-15 Min
# 91739         NaN        Warning       False      0-15 Min
# 91740         NaN       Citation       False      0-15 Min
#
#        drugs_related_stop district     stop_datetime
# 0                   False  Zone X4  2005-01-04 12:55
# 1                   False  Zone K3  2005-01-23 23:15
# 2                   False  Zone X4  2005-02-17 04:15
# 3                   False  Zone X1  2005-02-20 17:15
# 4                   False  Zone X3  2005-02-24 01:20
# ...                   ...      ...               ...
# 91736               False  Zone K2  2015-12-31 21:21
# 91737               False  Zone K3  2015-12-31 21:59
# 91738               False  Zone X3  2015-12-31 22:04
# 91739               False  Zone K3  2015-12-31 22:09
# 91740               False  Zone X4  2015-12-31 22:47
#
# [91741 rows x 14 columns]

# %%
df["stop_datetime"] = pd.to_datetime(df["stop_datetime"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               91741 non-null  object
#  1   stop_date           91741 non-null  object
#  2   stop_time           91741 non-null  object
#  3   county_name         0 non-null      float64
#  4   driver_gender       86536 non-null  object
#  5   driver_race         86539 non-null  object
#  6   violation_raw       86539 non-null  object
#  7   violation           86539 non-null  object
#  8   search_conducted    91741 non-null  bool
#  9   search_type         3307 non-null   object
#  10  stop_outcome        86539 non-null  object
#  11  is_arrested         86539 non-null  object
#  12  stop_duration       86539 non-null  object
#  13  drugs_related_stop  91741 non-null  bool
#  14  district            91741 non-null  object
#  15  stop_datetime       91741 non-null  datetime64[ns]
# dtypes: bool(2), datetime64[ns](1), float64(1), object(12)
# memory usage: 10.0+ MB

# %% [markdown]
# <span style="color:blue">**Criei uma nova coluna combinando as colunas stop_date e stop_time.**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (g) Por fim, transforme a coluna stop_datetime no índice do dataframe.
# </div>

# %%
df = df.set_index("stop_datetime")

# %%
df
# Out:
#                     state   stop_date stop_time  county_name driver_gender  \
# stop_datetime
# 2005-01-04 12:55:00    RI  2005-01-04     12:55          NaN             M
# 2005-01-23 23:15:00    RI  2005-01-23     23:15          NaN             M
# 2005-02-17 04:15:00    RI  2005-02-17     04:15          NaN             M
# 2005-02-20 17:15:00    RI  2005-02-20     17:15          NaN             M
# 2005-02-24 01:20:00    RI  2005-02-24     01:20          NaN             F
# ...                   ...         ...       ...          ...           ...
# 2015-12-31 21:21:00    RI  2015-12-31     21:21          NaN             F
# 2015-12-31 21:59:00    RI  2015-12-31     21:59          NaN             F
# 2015-12-31 22:04:00    RI  2015-12-31     22:04          NaN             M
# 2015-12-31 22:09:00    RI  2015-12-31     22:09          NaN             F
# 2015-12-31 22:47:00    RI  2015-12-31     22:47          NaN             M
#
#                     driver_race                   violation_raw  \
# stop_datetime
# 2005-01-04 12:55:00       White  Equipment/Inspection Violation
# 2005-01-23 23:15:00       White                        Speeding
# 2005-02-17 04:15:00       White                        Speeding
# 2005-02-20 17:15:00       White                Call for Service
# 2005-02-24 01:20:00       White                        Speeding
# ...                         ...                             ...
# 2015-12-31 21:21:00       Black         Other Traffic Violation
# 2015-12-31 21:59:00       White                        Speeding
# 2015-12-31 22:04:00       White         Other Traffic Violation
# 2015-12-31 22:09:00    Hispanic  Equipment/Inspection Violation
# 2015-12-31 22:47:00       White          Registration Violation
#
#                                violation  search_conducted search_type  \
# stop_datetime
# 2005-01-04 12:55:00            Equipment             False         NaN
# 2005-01-23 23:15:00             Speeding             False         NaN
# 2005-02-17 04:15:00             Speeding             False         NaN
# 2005-02-20 17:15:00                Other             False         NaN
# 2005-02-24 01:20:00             Speeding             False         NaN
# ...                                  ...               ...         ...
# 2015-12-31 21:21:00     Moving violation             False         NaN
# 2015-12-31 21:59:00             Speeding             False         NaN
# 2015-12-31 22:04:00     Moving violation             False         NaN
# 2015-12-31 22:09:00            Equipment             False         NaN
# 2015-12-31 22:47:00  Registration/plates             False         NaN
#
#                       stop_outcome is_arrested stop_duration  \
# stop_datetime
# 2005-01-04 12:55:00       Citation       False      0-15 Min
# 2005-01-23 23:15:00       Citation       False      0-15 Min
# 2005-02-17 04:15:00       Citation       False      0-15 Min
# 2005-02-20 17:15:00  Arrest Driver        True     16-30 Min
# 2005-02-24 01:20:00       Citation       False      0-15 Min
# ...                            ...         ...           ...
# 2015-12-31 21:21:00       Citation       False      0-15 Min
# 2015-12-31 21:59:00       Citation       False      0-15 Min
# 2015-12-31 22:04:00       Citation       False      0-15 Min
# 2015-12-31 22:09:00        Warning       False      0-15 Min
# 2015-12-31 22:47:00       Citation       False      0-15 Min
#
#                      drugs_related_stop district
# stop_datetime
# 2005-01-04 12:55:00               False  Zone X4
# 2005-01-23 23:15:00               False  Zone K3
# 2005-02-17 04:15:00               False  Zone X4
# 2005-02-20 17:15:00               False  Zone X1
# 2005-02-24 01:20:00               False  Zone X3
# ...                                 ...      ...
# 2015-12-31 21:21:00               False  Zone K2
# 2015-12-31 21:59:00               False  Zone K3
# 2015-12-31 22:04:00               False  Zone X3
# 2015-12-31 22:09:00               False  Zone K3
# 2015-12-31 22:47:00               False  Zone X4
#
# [91741 rows x 15 columns]

# %% [markdown]
# <span style="color:blue">**Transformei a coluna stop_datetime em Índice.**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# 2. Análise do gênero sobre as infrações
# O gênero do motorista influencia o comportamento da polícia durante uma parada no trânsito?
# Nesta parte, você explorará essa questão enquanto pratica filtragem, agrupamento e muito
# mais!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (a) Antes de comparar as infrações cometidas por cada gênero, você deve examinar as infra-
# ções cometidas por todos os motoristas para obter uma compreensão básica dos dados.
# Construa uma distribuição de frequências da variável violation e responda: qual a
# infração mais comum e a menos notificada?
# </div>

# %%
df["violation"].value_counts()
# Out:
# Speeding               48424
# Moving violation       16224
# Equipment              10922
# Other                   4410
# Registration/plates     3703
# Seat belt               2856
# Name: violation, dtype: int64

# %% [markdown]
# <span style="color:blue">**Mais comum : velocidade.**</span>

# %% [markdown]
# <span style="color:blue">**Menos comum : cinto de segurança.**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (b) O interesse agora é responder a seguinte questão: motoristas do sexo masculino e femi-
# nino tendem a cometer diferentes tipos de infrações de trânsito? Para isso, crie uma tabela
# de contingência para frequência absoluta e outra para frequência relativa, contendo a
# distribuição conjunta das variáveis driver_gender e violation.
# </div>

# %%
tabela = pd.crosstab(df["driver_gender"], df["violation"],
                    colnames=['Classe'],
                    margins=False)
tabela
# Out:
# Classe         Equipment  Moving violation  Other  Registration/plates  \
# driver_gender
# F                   2501              3286    707                 1056
# M                   8420             12938   3702                 2647
#
# Classe         Seat belt  Speeding
# driver_gender
# F                    578     15646
# M                   2278     32777

# %% [markdown]
# <div class="alert alert-block alert-info">
# (c) Construa um gráfico de barras agrupadas para ilustrar os dados das tabelas de contingência construídas;
# </div>

# %%
# %matplotlib inline
tabela.plot.bar(title = "Ranking de acidentes masculinos")
plt.grid()

# %% [markdown]
# <div class="alert alert-block alert-info">
# (d) Quando um motorista é parado por excesso de velocidade, muitas pessoas acreditam que
# o gênero influencia se o motorista receberá uma multa ou um aviso. Você pode encontrar
# evidências disso no conjunto de dados? Para tentar responder essa pergunta, crie uma
# tabela de contingência considerando as variáveis driver_gender e stop_outcome e
# então vai comparar a porcentagem de paradas resultados de uma "Citation"versus um
# "Warning"(veja o link que descreve as variáveis caso tenha dúvidas de compreensão);
# </div>

# %%
pd.crosstab(df["driver_gender"], df["stop_outcome"], normalize= True)*100
# Out:
# stop_outcome   Arrest Driver  Arrest Passenger   Citation       N/D  \
# driver_gender
# F                   0.642507          0.130581  24.557410  0.194139
# M                   2.518027          0.265785  64.528058  0.507303
#
# stop_outcome   No Action   Warning
# driver_gender
# F               0.232273  1.716049
# M               0.488814  4.219053

# %% [markdown]
# <span style="color:blue">**Feminino "Citation":24.557410**</span>

# %% [markdown]
# <span style="color:blue">**Masculino "Citation":64.528058**</span>

# %% [markdown]
# <span style="color:blue">**Diferença de 39,970648**</span>

# %% [markdown]
# <span style="color:blue">**Feminino "Warning":1.716049**</span>

# %% [markdown]
# <span style="color:blue">**Masculino "Warnig":4.219053**</span>

# %% [markdown]
# <span style="color:blue">**Diferença de 2,503004**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (e) O gênero afeta a escolha de veículos a serem revistados? Para responder essa pergunta,
# primeiro, calcule a porcentagem de todas as paradas no DataFrame que resultam em
# uma revista de veículo;
# </div>

# %%
df["search_conducted"].mean()*100
# Out:
# 3.604713268876511

# %% [markdown]
# <span style="color:blue">**De todas as paradas 3.6% são revistadas**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (f) Em seguida, filtre o DataFrame por gênero e calcule a taxa de pesquisa para cada grupo
# separadamente. Dica: você executará o mesmo cálculo para ambos os gêneros ao mesmo
# tempo usando groupby;
# </div>

# %%
x = df.groupby('driver_gender')[['search_conducted','violation']].sum()
x
# Out:
#                search_conducted
# driver_gender
# F                           456
# M                          2851

# %%
t = df["driver_gender"] == "F"
te = df[t]
te["search_conducted"].mean()*100
# Out:
# 1.9180617481282074

# %%
t1 = df['driver_gender'] == 'M'
te1 = df[t1]
te1["search_conducted"].mean()*100
# Out:
# 4.542557598546892

# %% [markdown]
# <span style="color:blue">**Sexo masculino: 2851 revistados, com a porcentagem de 4.5%**</span>

# %% [markdown]
# <span style="color:blue">**Sexo Feminino: 456 revistados, com a porcentagem de 1.9%**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (g) Considere agora a hipótese de que a taxa de revista varia de acordo com o tipo de infra-
# ção, e a diferença na taxa de revista entre homens e mulheres é porque eles tendem a
# cometer infrações diferentes. Calcule a taxa de infração para cada combinação de gênero
# e infração. Homens e mulheres são revistados com a mesma taxa para cada infração?
# </div>

# %%
masculino1 = df["driver_gender"] == "M"
masculino2 = df[masculino1]
x = masculino2["search_conducted"] == True
xa = masculino2[x]
xa["violation"].value_counts()
# Out:
# Speeding               914
# Moving violation       796
# Equipment              602
# Registration/plates    288
# Other                  171
# Seat belt               80
# Name: violation, dtype: int64

# %%
feminino1 = df["driver_gender"] == "F"
feminino2 = df[feminino1]
x1 = feminino2["search_conducted"] == True
xa1 = feminino2[x1]
xa1["violation"].value_counts()
# Out:
# Speeding               130
# Moving violation       129
# Equipment              100
# Registration/plates     58
# Other                   29
# Seat belt               10
# Name: violation, dtype: int64

# %% [markdown]
# <span style="color:blue">**As mulheres tem os números bem abaixo do que dos homens em relação da revista por gênero e infrações.**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# 3. Análise exploratória visual dos dados.
# É mais provável que você seja preso em uma determinada hora do dia? As paradas relacionadas
# às drogas estão aumentando? Nesta parte, você responderá a essas e outras questões analisando o conjunto de dados visualmente, uma vez que os gráficos podem ajudá-lo a entender
# as tendências de uma forma que o exame dos dados brutos não pode.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (a) Quando um policial para um motorista, uma pequena porcentagem dessas paradas termina em uma prisão. Isso é conhecido como taxa de prisão. Você descobrirá se a taxa de
# prisão varia de acordo com a hora do dia. Primeiro, você calculará a taxa de prisão em
# todas as paradas no DataFrame, calculando a média da coluna is_arrested ;
# </div>

# %%
df["is_arrested"].mean()
# Out:
# 0.03556777868937704

# %% [markdown]
# <span style="color:blue">**A média da coluna is_arrested é 0.03556777868937704.**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (b) Em seguida, você calculará a taxa de prisão por hora usando o atributo de hora do índice.
# A hora varia de 0 a 23, considerando que 0 é meia noite e 12h é meio dia. Para isso,
# agrupe (usando groupby) pelo atributo de hora do índice do DataFrame, calculando a
# média dos valores agrupados. No final crie uma nova variável hourly_arrest_rate
# com os valores encontrados da taxa de prisão por hora;
# </div>

# %%
media_ph = df["is_arrested"].groupby(by= df.index.hour).mean()
media_ph
# Out:
# stop_datetime
# 0     0.051420
# 1     0.064932
# 2     0.060798
# 3     0.060549
# 4     0.048000
# 5     0.042781
# 6     0.013813
# 7     0.013032
# 8     0.021854
# 9     0.025206
# 10    0.028213
# 11    0.028897
# 12    0.037399
# 13    0.030776
# 14    0.030605
# 15    0.030679
# 16    0.035281
# 17    0.040619
# 18    0.038186
# 19    0.032245
# 20    0.038107
# 21    0.064541
# 22    0.048666
# 23    0.047582
# Name: is_arrested, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
# (c) Agora crie um gráfico de linha mostrando a variável hourly_arrest_rate, colocando
# o rótulo Horas no eixo-x, e Taxa de Prisões, no eixo-y, e o título de Taxa de Prisões por Hora
# do Dia;
#     </div>

# %%
plt.plot(media_ph)
plt.xlabel("Horas")
plt.ylabel("Taxa de Prisões")
plt.title("Taxa de Prisões por Hora do Dia")
# Out:
# Text(0.5, 1.0, 'Taxa de Prisões por Hora do Dia')

# %% [markdown]
# <div class="alert alert-block alert-info">
# (d) Em uma pequena parte das paradas de trânsito, drogas são encontradas no veículo durante uma busca. Agora, você avaliará se essas interrupções relacionadas à drogas estão
# se tornando mais comuns com o tempo. A coluna booleana drug_related_stop indica
# se drogas foram encontradas durante uma determinada parada. Você calculará a taxa
# anual de drogas reamostrando essa coluna e, em seguida, usará um gráfico de linha para
# visualizar como a taxa mudou ao longo do tempo;
#     </div>

# %%
Annual_drug_rate = df["drugs_related_stop"].groupby(by= df.index.year).mean()
Annual_drug_rate
# Out:
# stop_datetime
# 2005    0.006390
# 2006    0.006913
# 2007    0.007520
# 2008    0.006998
# 2009    0.009079
# 2010    0.009407
# 2011    0.009035
# 2012    0.009388
# 2013    0.012283
# 2014    0.013280
# 2015    0.011787
# Name: drugs_related_stop, dtype: float64

# %%
plt.plot(Annual_drug_rate)
plt.xlabel("Ano")
plt.ylabel("Taxa de drogas encontradas")
plt.title("Taxa anual de prisões por ano")
# Out:
# Text(0.5, 1.0, 'Taxa anual de prisões por ano')

# %% [markdown]
# <div class="alert alert-block alert-info">
# (e) Ainda falando sobre drogas, consideremos a hipótese de que, o aumento ou a diminuição das apreensões de drogas estão associadas ao aumento ou diminuição das abordagens políciais, ou seja, mais abordagens, geram mais apreensões e menos abordagens, menos apreensões de drogas. Podemos testar essa hipótese calculando a taxa de
# abordagens anual e, em seguida, comparando-a com a taxa anual de medicamentos.
# Se a hipótese for verdadeira, você verá que ambas as taxas aumentam com o tempo.
# Para isso, calcule a taxa de pesquisa anual reamostrando a coluna search_conducted
# e salve o resultado como Annual_search_rate. Concatene Annual_drug_rate e
# Annual_search_rate ao longo do eixo das colunas e gere gráficos de linha para os
# dados desse resultado da concatenação;
# </div>

# %%
Annual_search_rate = df["search_conducted"].groupby(by = df.index.year).mean()
Annual_search_rate
# Out:
# stop_datetime
# 2005    0.048323
# 2006    0.039773
# 2007    0.041567
# 2008    0.037585
# 2009    0.045780
# 2010    0.041808
# 2011    0.033129
# 2012    0.031808
# 2013    0.028164
# 2014    0.030544
# 2015    0.027384
# Name: search_conducted, dtype: float64

# %%
relacao_taxas = pd.concat([Annual_drug_rate, Annual_search_rate], axis = 1)
relacao_taxas
# Out:
#                drugs_related_stop  search_conducted
# stop_datetime
# 2005                     0.006390          0.048323
# 2006                     0.006913          0.039773
# 2007                     0.007520          0.041567
# 2008                     0.006998          0.037585
# 2009                     0.009079          0.045780
# 2010                     0.009407          0.041808
# 2011                     0.009035          0.033129
# 2012                     0.009388          0.031808
# 2013                     0.012283          0.028164
# 2014                     0.013280          0.030544
# 2015                     0.011787          0.027384

# %%
plt.plot(relacao_taxas)
plt.xlabel("Ano")
plt.title("Teste de hipótese")
# Out:
# Text(0.5, 1.0, 'Teste de hipótese')

# %% [markdown]
# <span style="color:blue">**Taxa de revista está diminuindo e a taxa de drogas encontradas estão aumentando.**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (f) O estado de Rhode Island está dividido em seis distritos policiais, também conhecidos
# como zonas. Como as zonas se comparam em termos de quais infrações são detectadas
# pela polícia? Para isso, crie uma distribuição conjunta entre as variáveis district e
# violation, usando uma tabela de contingência. Depois, selecione as linhas das zonas
# ’Zona K1’ a ’Zona K3’, gere um gráfico de barras agrupadas que ilustre os resultados
# obtido na tabela, e responda a questão colocada.
# </div>

# %%
a = pd.crosstab(df["district"], df["violation"])
a
# Out:
# violation  Equipment  Moving violation  Other  Registration/plates  Seat belt  \
# district
# Zone K1          673              1254    290                  120          0
# Zone K2         2061              2962    942                  768        481
# Zone K3         2302              2898    706                  695        638
# Zone X1          296               671    143                   38         74
# Zone X3         2049              3086    769                  671        820
# Zone X4         3541              5353   1560                 1411        843
#
# violation  Speeding
# district
# Zone K1        5960
# Zone K2       10448
# Zone K3       12323
# Zone X1        1119
# Zone X3        8779
# Zone X4        9795

# %%
b = a.loc[["Zone K1","Zone K2", "Zone K3"]]
b.plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='district'>

# %% [markdown]
# <span style="color:blue">**Zone K1 tem as infrações bem abaixo das outras zonas.**</span>

# %% [markdown]
# <span style="color:blue">**Zone K2 tem o número de infrações bem parecido da Zone K3.**</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# 4. Analisando o efeito do clima no policiamento
# Nesta última parte, você usará um segundo conjunto de dados, weather.csv, para explorar
# o impacto das condições meteorológicas no comportamento da polícia durante as paradas de
# trânsito. Você vai praticar mesclar e remodelar conjuntos de dados, avaliando se uma fonte de
# dados é confiável, trabalhando com dados categóricos e outras habilidades avançadas.
# </div>

# %%
df2
# Out:
#           STATION        DATE  TAVG  TMIN  TMAX   AWND  WSF2  WT01  WT02  \
# 0     USW00014765  2005-01-01  44.0    35    53   8.95  25.1   1.0   NaN
# 1     USW00014765  2005-01-02  36.0    28    44   9.40  14.1   NaN   NaN
# 2     USW00014765  2005-01-03  49.0    44    53   6.93  17.0   1.0   NaN
# 3     USW00014765  2005-01-04  42.0    39    45   6.93  16.1   1.0   NaN
# 4     USW00014765  2005-01-05  36.0    28    43   7.83  17.0   1.0   NaN
# ...           ...         ...   ...   ...   ...    ...   ...   ...   ...
# 4012  USW00014765  2015-12-27  51.0    44    61   9.17  28.0   1.0   NaN
# 4013  USW00014765  2015-12-28  40.0    30    44  12.30  23.0   NaN   NaN
# 4014  USW00014765  2015-12-29  33.0    28    40  12.53  18.1   1.0   NaN
# 4015  USW00014765  2015-12-30  30.0    27    35   6.93  15.0   1.0   NaN
# 4016  USW00014765  2015-12-31  39.0    35    50   8.05  18.1   1.0   NaN
#
#       WT03  ...  WT11  WT13  WT14  WT15  WT16  WT17  WT18  WT19  WT21  WT22
# 0      NaN  ...   NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1      NaN  ...   NaN   NaN   NaN   NaN   1.0   NaN   1.0   NaN   NaN   NaN
# 2      NaN  ...   NaN   1.0   NaN   NaN   1.0   NaN   NaN   NaN   NaN   NaN
# 3      NaN  ...   NaN   1.0   1.0   NaN   1.0   NaN   NaN   NaN   NaN   NaN
# 4      NaN  ...   NaN   1.0   NaN   NaN   1.0   NaN   1.0   NaN   NaN   NaN
# ...    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 4012   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4013   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4014   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4015   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4016   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [4017 rows x 27 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# (a) Comece explorando as temperaturas apresentadas no conjunto de dados: carregue o conjunto, selecione as variáveis relativas à temperatura (TMIN, TAVG, TMAX), imprima as
# principais medidas resumo usando o comando describe e plote os três boxplots dessas
# variáveis em um mesmo gráfico. O que você poderia comentar sobre as temperaturas, com
# base nos resultados obtidos? PS.: ao decidir se os valores parecem razoáveis, lembre-se
# de que a temperatura é medida em graus Fahrenheit, não Celsius!
# </div>

# %%
temp = pd.concat([df2["TMIN"],df2["TAVG"],df2["TMAX"]], axis = 1).describe()
temp
# Out:
#               TMIN         TAVG         TMAX
# count  4017.000000  1217.000000  4017.000000
# mean     43.484441    52.493016    61.268608
# std      17.020298    17.830714    18.199517
# min      -5.000000     6.000000    15.000000
# 25%      30.000000    39.000000    47.000000
# 50%      44.000000    54.000000    62.000000
# 75%      58.000000    68.000000    77.000000
# max      77.000000    86.000000   102.000000

# %%
temp.plot(kind = "bar")
plt.grid()

# %% [markdown]
# <div class="alert alert-block alert-info">
# (b) Para a variável TDIFF, que representa a diferença entre as temperaturas, apresente as
# medidas resumo e plote um histograma para essa variável. O que pode dizer sobre a
# distribuição de dados?
# </div>

# %%
df2['TDIFF'] = df2.apply(lambda x: x["TMAX"] - x["TMIN"], axis = 1)
tdiff = df2['TDIFF'].describe()
tdiff
# Out:
# count    4017.000000
# mean       17.784167
# std         6.350720
# min         2.000000
# 25%        14.000000
# 50%        18.000000
# 75%        22.000000
# max        43.000000
# Name: TDIFF, dtype: float64

# %%
plt.hist(tdiff)
# Out:
# (array([7., 0., 0., 0., 0., 0., 0., 0., 0., 1.]),
#  array([2.0000e+00, 4.0350e+02, 8.0500e+02, 1.2065e+03, 1.6080e+03,
#         2.0095e+03, 2.4110e+03, 2.8125e+03, 3.2140e+03, 3.6155e+03,
#         4.0170e+03]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# <div class="alert alert-block alert-info">
# (c) Você agora preparará os DataFrames das abordagens de trânsito e de classificação do
# clima (o dessa sessão) para que estejam prontos para serem mesclados. No DataFrame
# sobre abordagens no trânsito, você transformará o índice stop_datetime para uma coluna (reset_index), pois o índice será perdido durante a mesclagem. Com o DataFrame
# meteorológico, selecione as colunas DATE e rating e coloque em um novo dataframe;
# </div>

# %%
df.reset_index(inplace = True)
df
# Out:
#             stop_datetime state   stop_date stop_time  county_name  \
# 0     2005-01-04 12:55:00    RI  2005-01-04     12:55          NaN
# 1     2005-01-23 23:15:00    RI  2005-01-23     23:15          NaN
# 2     2005-02-17 04:15:00    RI  2005-02-17     04:15          NaN
# 3     2005-02-20 17:15:00    RI  2005-02-20     17:15          NaN
# 4     2005-02-24 01:20:00    RI  2005-02-24     01:20          NaN
# ...                   ...   ...         ...       ...          ...
# 91736 2015-12-31 21:21:00    RI  2015-12-31     21:21          NaN
# 91737 2015-12-31 21:59:00    RI  2015-12-31     21:59          NaN
# 91738 2015-12-31 22:04:00    RI  2015-12-31     22:04          NaN
# 91739 2015-12-31 22:09:00    RI  2015-12-31     22:09          NaN
# 91740 2015-12-31 22:47:00    RI  2015-12-31     22:47          NaN
#
#       driver_gender driver_race                   violation_raw  \
# 0                 M       White  Equipment/Inspection Violation
# 1                 M       White                        Speeding
# 2                 M       White                        Speeding
# 3                 M       White                Call for Service
# 4                 F       White                        Speeding
# ...             ...         ...                             ...
# 91736             F       Black         Other Traffic Violation
# 91737             F       White                        Speeding
# 91738             M       White         Other Traffic Violation
# 91739             F    Hispanic  Equipment/Inspection Violation
# 91740             M       White          Registration Violation
#
#                  violation  search_conducted search_type   stop_outcome  \
# 0                Equipment             False         NaN       Citation
# 1                 Speeding             False         NaN       Citation
# 2                 Speeding             False         NaN       Citation
# 3                    Other             False         NaN  Arrest Driver
# 4                 Speeding             False         NaN       Citation
# ...                    ...               ...         ...            ...
# 91736     Moving violation             False         NaN       Citation
# 91737             Speeding             False         NaN       Citation
# 91738     Moving violation             False         NaN       Citation
# 91739            Equipment             False         NaN        Warning
# 91740  Registration/plates             False         NaN       Citation
#
#       is_arrested stop_duration  drugs_related_stop district
# 0           False      0-15 Min               False  Zone X4
# 1           False      0-15 Min               False  Zone K3
# 2           False      0-15 Min               False  Zone X4
# 3            True     16-30 Min               False  Zone X1
# 4           False      0-15 Min               False  Zone X3
# ...           ...           ...                 ...      ...
# 91736       False      0-15 Min               False  Zone K2
# 91737       False      0-15 Min               False  Zone K3
# 91738       False      0-15 Min               False  Zone X3
# 91739       False      0-15 Min               False  Zone K3
# 91740       False      0-15 Min               False  Zone X4
#
# [91741 rows x 16 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# (d) Agora, mescle os dataframes gerados em um novo dataframe, unidos usando a coluna
# stop_date de do dataframe policial e a coluna DATE do novo dataframe gerado a partir
# dos dados meteorológicos. Assim que a mesclagem for concluída, defina stop_datetime
# novamente como o índice;
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# (e) A partir desse novo dataframe criado, levante duas questões e as responda usando qualquer técnica que ache necessária.
# </div>
